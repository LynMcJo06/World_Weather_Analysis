# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library
import requests

# Import the API
from config2 import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []

#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list. 
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
# Starting URL for Weather Map API call.  
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_wxdesc = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Weather Description": city_wxdesc,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | clyde river
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | zyryanka
# Processing Record 4 of Set 1 | auki
# Processing Record 5 of Set 1 | raudeberg
# Processing Record 6 of Set 1 | vostok
# Processing Record 7 of Set 1 | emmett
# Processing Record 8 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | thompson
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | dongsheng
# Processing Record 14 of Set 1 | cam pha
# City not found. Skipping...
# Processing Record 15 of Set 1 | carberry
# Processing Record 16 of Set 1 | avarua
# Processing Record 17 of Set 1 | taree
# Processing Record 18 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 1 | sur
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | balkanabat
# Processing Record 22 of Set 1 | lloydminster
# Processing Record 23 of Set 1 | bela
# Processing Record 24 of Set 1 | khromtau
# Processing Record 25 of Set 1 | shancheng
# Processing Record 26 of Set 1 | ostrovnoy
# Processing Record 27 of Set 1 | tual
# Processing Record 28 of Set 1 | kyren
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | tuktoyaktuk
# Processing Record 31 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 1 | khatanga
# Processing Record 33 of Set 1 | bestobe
# Processing Record 34 of Set 1 | kavaratti
# Processing Record 35 of Set 1 | yaan
# Processing Record 36 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 1 | skelleftea
# Processing Record 38 of Set 1 | bingol
# Processing Record 39 of Set 1 | pangnirtung
# Processing Record 40 of Set 1 | manacapuru
# Processing Record 41 of Set 1 | dikson
# Processing Record 42 of Set 1 | laguna
# Processing Record 43 of Set 1 | lambarene
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | jiwani
# Processing Record 47 of Set 1 | saint-philippe
# Processing Record 48 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | mount isa
# Processing Record 1 of Set 2 | zhezkazgan
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | rikitea
# Processing Record 4 of Set 2 | butaritari
# Processing Record 5 of Set 2 | narsaq
# Processing Record 6 of Set 2 | kaitangata
# Processing Record 7 of Set 2 | korla
# Processing Record 8 of Set 2 | lebu
# Processing Record 9 of Set 2 | bundaberg
# Processing Record 10 of Set 2 | nouadhibou
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | mangrol
# Processing Record 13 of Set 2 | nemuro
# Processing Record 14 of Set 2 | carauari
# Processing Record 15 of Set 2 | mount gambier
# Processing Record 16 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | honningsvag
# Processing Record 19 of Set 2 | barrow
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | hithadhoo
# Processing Record 22 of Set 2 | banda aceh
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | naze
# Processing Record 25 of Set 2 | stoyba
# City not found. Skipping...
# Processing Record 26 of Set 2 | ilulissat
# Processing Record 27 of Set 2 | margate
# Processing Record 28 of Set 2 | qaanaaq
# Processing Record 29 of Set 2 | san patricio
# Processing Record 30 of Set 2 | am timan
# Processing Record 31 of Set 2 | balabac
# Processing Record 32 of Set 2 | dunedin
# Processing Record 33 of Set 2 | mar del plata
# Processing Record 34 of Set 2 | safaqis
# City not found. Skipping...
# Processing Record 35 of Set 2 | busselton
# Processing Record 36 of Set 2 | norman wells
# Processing Record 37 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 38 of Set 2 | karamay
# City not found. Skipping...
# Processing Record 39 of Set 2 | cape town
# Processing Record 40 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 41 of Set 2 | salalah
# Processing Record 42 of Set 2 | iqaluit
# Processing Record 43 of Set 2 | sioux lookout
# Processing Record 44 of Set 2 | mwense
# Processing Record 45 of Set 2 | okha
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | ginda
# Processing Record 48 of Set 2 | ende
# Processing Record 49 of Set 2 | vardo
# Processing Record 50 of Set 2 | bredasdorp
# Processing Record 1 of Set 3 | constitucion
# Processing Record 2 of Set 3 | saldanha
# Processing Record 3 of Set 3 | chokurdakh
# Processing Record 4 of Set 3 | albany
# Processing Record 5 of Set 3 | vestmanna
# Processing Record 6 of Set 3 | severo-kurilsk
# Processing Record 7 of Set 3 | georgetown
# Processing Record 8 of Set 3 | faanui
# Processing Record 9 of Set 3 | castro
# Processing Record 10 of Set 3 | whitianga
# Processing Record 11 of Set 3 | padang
# Processing Record 12 of Set 3 | kavieng
# Processing Record 13 of Set 3 | nara
# Processing Record 14 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 3 | seoul
# Processing Record 16 of Set 3 | souillac
# Processing Record 17 of Set 3 | lagoa
# Processing Record 18 of Set 3 | burica
# City not found. Skipping...
# Processing Record 19 of Set 3 | klaeng
# Processing Record 20 of Set 3 | salyan
# Processing Record 21 of Set 3 | newberry
# Processing Record 22 of Set 3 | benguela
# Processing Record 23 of Set 3 | boddam
# Processing Record 24 of Set 3 | zhigansk
# Processing Record 25 of Set 3 | saskylakh
# Processing Record 26 of Set 3 | waterloo
# Processing Record 27 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 3 | torbay
# Processing Record 29 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 30 of Set 3 | hofn
# Processing Record 31 of Set 3 | rio claro
# Processing Record 32 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 3 | daru
# Processing Record 34 of Set 3 | arraial do cabo
# Processing Record 35 of Set 3 | port blair
# Processing Record 36 of Set 3 | the valley
# Processing Record 37 of Set 3 | nikolskoye
# Processing Record 38 of Set 3 | olinda
# Processing Record 39 of Set 3 | east london
# Processing Record 40 of Set 3 | tessalit
# Processing Record 41 of Set 3 | hilo
# Processing Record 42 of Set 3 | uchaly
# Processing Record 43 of Set 3 | chaplygin
# Processing Record 44 of Set 3 | rajauri
# Processing Record 45 of Set 3 | hami
# Processing Record 46 of Set 3 | atambua
# Processing Record 47 of Set 3 | belyy yar
# Processing Record 48 of Set 3 | cherskiy
# Processing Record 49 of Set 3 | jinka
# Processing Record 50 of Set 3 | pravokumskoye
# Processing Record 1 of Set 4 | catamarca
# Processing Record 2 of Set 4 | hermanus
# Processing Record 3 of Set 4 | tiksi
# Processing Record 4 of Set 4 | jalu
# Processing Record 5 of Set 4 | mahebourg
# Processing Record 6 of Set 4 | suslonger
# Processing Record 7 of Set 4 | bethel
# Processing Record 8 of Set 4 | grand gaube
# Processing Record 9 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 11 of Set 4 | airai
# Processing Record 12 of Set 4 | vettavalam
# Processing Record 13 of Set 4 | pervomayskoye
# Processing Record 14 of Set 4 | zemio
# Processing Record 15 of Set 4 | buta
# Processing Record 16 of Set 4 | richards bay
# Processing Record 17 of Set 4 | moose factory
# Processing Record 18 of Set 4 | muros
# Processing Record 19 of Set 4 | burnie
# Processing Record 20 of Set 4 | acapulco
# Processing Record 21 of Set 4 | caibarien
# Processing Record 22 of Set 4 | katsuura
# Processing Record 23 of Set 4 | los llanos de aridane
# Processing Record 24 of Set 4 | dzaoudzi
# Processing Record 25 of Set 4 | lubango
# Processing Record 26 of Set 4 | uberlandia
# Processing Record 27 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 4 | truro
# Processing Record 29 of Set 4 | taber
# Processing Record 30 of Set 4 | carnarvon
# Processing Record 31 of Set 4 | abha
# Processing Record 32 of Set 4 | sola
# Processing Record 33 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 4 | kodiak
# Processing Record 35 of Set 4 | belaya gora
# Processing Record 36 of Set 4 | geraldton
# Processing Record 37 of Set 4 | havoysund
# Processing Record 38 of Set 4 | windhoek
# Processing Record 39 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 4 | salinopolis
# Processing Record 41 of Set 4 | zhigalovo
# Processing Record 42 of Set 4 | gurskoye
# City not found. Skipping...
# Processing Record 43 of Set 4 | waraseoni
# Processing Record 44 of Set 4 | karratha
# Processing Record 45 of Set 4 | esperance
# Processing Record 46 of Set 4 | flinders
# Processing Record 47 of Set 4 | nova granada
# Processing Record 48 of Set 4 | kununurra
# Processing Record 49 of Set 4 | ancud
# Processing Record 50 of Set 4 | yerbogachen
# Processing Record 1 of Set 5 | kamenka
# Processing Record 2 of Set 5 | kruisfontein
# Processing Record 3 of Set 5 | plaster rock
# Processing Record 4 of Set 5 | cabo san lucas
# Processing Record 5 of Set 5 | komsomolskiy
# Processing Record 6 of Set 5 | pevek
# Processing Record 7 of Set 5 | srednekolymsk
# Processing Record 8 of Set 5 | husavik
# Processing Record 9 of Set 5 | bambous virieux
# Processing Record 10 of Set 5 | ladson
# Processing Record 11 of Set 5 | umm kaddadah
# Processing Record 12 of Set 5 | mercedes
# Processing Record 13 of Set 5 | tutoia
# Processing Record 14 of Set 5 | aloleng
# Processing Record 15 of Set 5 | dukat
# Processing Record 16 of Set 5 | lompoc
# Processing Record 17 of Set 5 | nanakuli
# Processing Record 18 of Set 5 | baykit
# Processing Record 19 of Set 5 | hasaki
# Processing Record 20 of Set 5 | tairua
# Processing Record 21 of Set 5 | leningradskiy
# Processing Record 22 of Set 5 | yulara
# Processing Record 23 of Set 5 | rovaniemi
# Processing Record 24 of Set 5 | kemin
# Processing Record 25 of Set 5 | coronel bogado
# Processing Record 26 of Set 5 | hokitika
# Processing Record 27 of Set 5 | chulman
# Processing Record 28 of Set 5 | bijie
# Processing Record 29 of Set 5 | bathurst
# Processing Record 30 of Set 5 | barreirinhas
# Processing Record 31 of Set 5 | gawler
# Processing Record 32 of Set 5 | santa rosalia
# Processing Record 33 of Set 5 | lasa
# Processing Record 34 of Set 5 | belinskiy
# Processing Record 35 of Set 5 | awjilah
# Processing Record 36 of Set 5 | touros
# Processing Record 37 of Set 5 | lata
# Processing Record 38 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 39 of Set 5 | port elizabeth
# Processing Record 40 of Set 5 | verkhnevilyuysk
# Processing Record 41 of Set 5 | ugento
# Processing Record 42 of Set 5 | gat
# Processing Record 43 of Set 5 | chuy
# Processing Record 44 of Set 5 | saint george
# Processing Record 45 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 46 of Set 5 | dwarka
# Processing Record 47 of Set 5 | chara
# Processing Record 48 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 5 | miguelopolis
# Processing Record 50 of Set 5 | avera
# Processing Record 1 of Set 6 | kathmandu
# Processing Record 2 of Set 6 | mineros
# Processing Record 3 of Set 6 | tuatapere
# Processing Record 4 of Set 6 | vila velha
# Processing Record 5 of Set 6 | ossora
# Processing Record 6 of Set 6 | macusani
# Processing Record 7 of Set 6 | provideniya
# Processing Record 8 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 9 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 10 of Set 6 | ondangwa
# Processing Record 11 of Set 6 | xining
# Processing Record 12 of Set 6 | manzanillo
# Processing Record 13 of Set 6 | baoshan
# Processing Record 14 of Set 6 | nanortalik
# Processing Record 15 of Set 6 | teguldet
# Processing Record 16 of Set 6 | kuching
# Processing Record 17 of Set 6 | barsi
# Processing Record 18 of Set 6 | moron
# Processing Record 19 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 20 of Set 6 | kutum
# Processing Record 21 of Set 6 | rio gallegos
# Processing Record 22 of Set 6 | comodoro rivadavia
# Processing Record 23 of Set 6 | kharp
# Processing Record 24 of Set 6 | brae
# Processing Record 25 of Set 6 | gold coast
# Processing Record 26 of Set 6 | coxim
# Processing Record 27 of Set 6 | bengkulu
# Processing Record 28 of Set 6 | quatre cocos
# Processing Record 29 of Set 6 | dingle
# Processing Record 30 of Set 6 | port lincoln
# Processing Record 31 of Set 6 | hobyo
# Processing Record 32 of Set 6 | cajaruro
# Processing Record 33 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 34 of Set 6 | te anau
# Processing Record 35 of Set 6 | nizhniy kuranakh
# Processing Record 36 of Set 6 | selenduma
# Processing Record 37 of Set 6 | andros town
# Processing Record 38 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 39 of Set 6 | soubre
# Processing Record 40 of Set 6 | ortakoy
# Processing Record 41 of Set 6 | liverpool
# Processing Record 42 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 6 | carutapera
# Processing Record 44 of Set 6 | russell
# Processing Record 45 of Set 6 | aklavik
# Processing Record 46 of Set 6 | sokoni
# Processing Record 47 of Set 6 | zlitan
# Processing Record 48 of Set 6 | cayenne
# Processing Record 49 of Set 6 | bielsk podlaski
# Processing Record 50 of Set 6 | denpasar
# Processing Record 1 of Set 7 | fortuna
# Processing Record 2 of Set 7 | bakchar
# Processing Record 3 of Set 7 | fairbanks
# Processing Record 4 of Set 7 | kalmunai
# Processing Record 5 of Set 7 | talmenka
# Processing Record 6 of Set 7 | moissala
# Processing Record 7 of Set 7 | sri aman
# Processing Record 8 of Set 7 | halifax
# Processing Record 9 of Set 7 | waipawa
# Processing Record 10 of Set 7 | longyearbyen
# Processing Record 11 of Set 7 | camocim
# Processing Record 12 of Set 7 | at-bashi
# Processing Record 13 of Set 7 | smithfield
# Processing Record 14 of Set 7 | alofi
# Processing Record 15 of Set 7 | rocha
# Processing Record 16 of Set 7 | suleja
# Processing Record 17 of Set 7 | ponta do sol
# Processing Record 18 of Set 7 | northam
# Processing Record 19 of Set 7 | coihaique
# Processing Record 20 of Set 7 | itagiba
# Processing Record 21 of Set 7 | soyo
# Processing Record 22 of Set 7 | phek
# Processing Record 23 of Set 7 | morbach
# Processing Record 24 of Set 7 | kyshtovka
# Processing Record 25 of Set 7 | conde
# Processing Record 26 of Set 7 | hervey bay
# Processing Record 27 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 7 | cidreira
# Processing Record 30 of Set 7 | canguaretama
# Processing Record 31 of Set 7 | apopka
# Processing Record 32 of Set 7 | alice springs
# Processing Record 33 of Set 7 | san policarpo
# Processing Record 34 of Set 7 | haapiti
# Processing Record 35 of Set 7 | kieta
# Processing Record 36 of Set 7 | muisne
# Processing Record 37 of Set 7 | plettenberg bay
# Processing Record 38 of Set 7 | asau
# Processing Record 39 of Set 7 | portland
# Processing Record 40 of Set 7 | seljord
# Processing Record 41 of Set 7 | clovis
# Processing Record 42 of Set 7 | yarada
# Processing Record 43 of Set 7 | pisco
# Processing Record 44 of Set 7 | timmins
# Processing Record 45 of Set 7 | upington
# Processing Record 46 of Set 7 | camana
# Processing Record 47 of Set 7 | akola
# Processing Record 48 of Set 7 | tulum
# Processing Record 49 of Set 7 | mizan teferi
# Processing Record 50 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 1 of Set 8 | faya
# Processing Record 2 of Set 8 | lakeway
# Processing Record 3 of Set 8 | bac lieu
# Processing Record 4 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 8 | puerto del rosario
# Processing Record 6 of Set 8 | ilhabela
# Processing Record 7 of Set 8 | carballo
# Processing Record 8 of Set 8 | buala
# Processing Record 9 of Set 8 | taburao
# City not found. Skipping...
# Processing Record 10 of Set 8 | biga
# Processing Record 11 of Set 8 | kurchum
# Processing Record 12 of Set 8 | kudahuvadhoo
# Processing Record 13 of Set 8 | oussouye
# Processing Record 14 of Set 8 | sambava
# Processing Record 15 of Set 8 | sorland
# Processing Record 16 of Set 8 | isangel
# Processing Record 17 of Set 8 | santiago del estero
# Processing Record 18 of Set 8 | juba
# Processing Record 19 of Set 8 | fare
# Processing Record 20 of Set 8 | hovd
# Processing Record 21 of Set 8 | half moon bay
# Processing Record 22 of Set 8 | aketi
# Processing Record 23 of Set 8 | anadyr
# Processing Record 24 of Set 8 | andapa
# Processing Record 25 of Set 8 | rawson
# Processing Record 26 of Set 8 | espumoso
# Processing Record 27 of Set 8 | fuyu
# Processing Record 28 of Set 8 | puerto colombia
# Processing Record 29 of Set 8 | vila franca do campo
# Processing Record 30 of Set 8 | meulaboh
# Processing Record 31 of Set 8 | whitecourt
# Processing Record 32 of Set 8 | pacific grove
# Processing Record 33 of Set 8 | bonthe
# Processing Record 34 of Set 8 | road town
# Processing Record 35 of Set 8 | bathsheba
# Processing Record 36 of Set 8 | ixtapa
# Processing Record 37 of Set 8 | bahia honda
# Processing Record 38 of Set 8 | visby
# Processing Record 39 of Set 8 | kushmurun
# Processing Record 40 of Set 8 | chippewa falls
# Processing Record 41 of Set 8 | tongliao
# Processing Record 42 of Set 8 | victoria
# Processing Record 43 of Set 8 | bukachacha
# Processing Record 44 of Set 8 | kumphawapi
# Processing Record 45 of Set 8 | san vicente
# Processing Record 46 of Set 8 | iracoubo
# Processing Record 47 of Set 8 | bandipur
# Processing Record 48 of Set 8 | ocampo
# Processing Record 49 of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 50 of Set 8 | fort nelson
# Processing Record 1 of Set 9 | neiafu
# Processing Record 2 of Set 9 | lavrentiya
# Processing Record 3 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 9 | egvekinot
# Processing Record 5 of Set 9 | kedrovyy
# Processing Record 6 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 9 | charagua
# Processing Record 8 of Set 9 | krasnoturinsk
# Processing Record 9 of Set 9 | wyszkow
# Processing Record 10 of Set 9 | sladkovo
# Processing Record 11 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 12 of Set 9 | haines junction
# Processing Record 13 of Set 9 | deputatskiy
# Processing Record 14 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 15 of Set 9 | edd
# Processing Record 16 of Set 9 | vilyuysk
# Processing Record 17 of Set 9 | sao filipe
# Processing Record 18 of Set 9 | penzance
# Processing Record 19 of Set 9 | westport
# Processing Record 20 of Set 9 | niamey
# Processing Record 21 of Set 9 | aberdeen
# Processing Record 22 of Set 9 | juneau
# Processing Record 23 of Set 9 | umm ruwabah
# City not found. Skipping...
# Processing Record 24 of Set 9 | sijunjung
# Processing Record 25 of Set 9 | namibe
# Processing Record 26 of Set 9 | kingisepp
# Processing Record 27 of Set 9 | lac du bonnet
# Processing Record 28 of Set 9 | thayetmyo
# Processing Record 29 of Set 9 | sexsmith
# Processing Record 30 of Set 9 | dhidhdhoo
# Processing Record 31 of Set 9 | bandarbeyla
# Processing Record 32 of Set 9 | aksu
# Processing Record 33 of Set 9 | palmares do sul
# Processing Record 34 of Set 9 | santa barbara
# Processing Record 35 of Set 9 | uribia
# Processing Record 36 of Set 9 | ribeira grande
# Processing Record 37 of Set 9 | taltal
# Processing Record 38 of Set 9 | ust-omchug
# Processing Record 39 of Set 9 | panuco
# Processing Record 40 of Set 9 | salinas
# Processing Record 41 of Set 9 | pietarsaari
# Processing Record 42 of Set 9 | umm lajj
# Processing Record 43 of Set 9 | rognan
# Processing Record 44 of Set 9 | saryg-sep
# Processing Record 45 of Set 9 | nishihara
# Processing Record 46 of Set 9 | ust-ishim
# Processing Record 47 of Set 9 | trairi
# Processing Record 48 of Set 9 | bagotville
# Processing Record 49 of Set 9 | aranos
# Processing Record 50 of Set 9 | morros
# Processing Record 1 of Set 10 | sal rei
# Processing Record 2 of Set 10 | cartagena
# Processing Record 3 of Set 10 | safranbolu
# Processing Record 4 of Set 10 | diffa
# Processing Record 5 of Set 10 | sandwick
# Processing Record 6 of Set 10 | vrangel
# Processing Record 7 of Set 10 | upernavik
# Processing Record 8 of Set 10 | lorengau
# Processing Record 9 of Set 10 | beypur
# City not found. Skipping...
# Processing Record 10 of Set 10 | valparaiso
# Processing Record 11 of Set 10 | charters towers
# Processing Record 12 of Set 10 | limon
# Processing Record 13 of Set 10 | jaynagar-majilpur
# Processing Record 14 of Set 10 | sitka
# Processing Record 15 of Set 10 | rassvet
# Processing Record 16 of Set 10 | graulhet
# Processing Record 17 of Set 10 | siddhapur
# Processing Record 18 of Set 10 | hamilton
# Processing Record 19 of Set 10 | camacupa
# Processing Record 20 of Set 10 | coquimbo
# Processing Record 21 of Set 10 | nantucket
# Processing Record 22 of Set 10 | palmer
# Processing Record 23 of Set 10 | college
# Processing Record 24 of Set 10 | kolda
# Processing Record 25 of Set 10 | ballina
# Processing Record 26 of Set 10 | mao
# Processing Record 27 of Set 10 | kayerkan
# Processing Record 28 of Set 10 | bela vista de goias
# Processing Record 29 of Set 10 | santiago de cao
# Processing Record 30 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 10 | matara
# Processing Record 32 of Set 10 | jumla
# Processing Record 33 of Set 10 | athabasca
# Processing Record 34 of Set 10 | lexington
# Processing Record 35 of Set 10 | urumqi
# Processing Record 36 of Set 10 | amarante do maranhao
# Processing Record 37 of Set 10 | harnosand
# Processing Record 38 of Set 10 | zanesville
# Processing Record 39 of Set 10 | bushenyi
# Processing Record 40 of Set 10 | sahuaripa
# Processing Record 41 of Set 10 | quimper
# Processing Record 42 of Set 10 | lichinga
# Processing Record 43 of Set 10 | birjand
# Processing Record 44 of Set 10 | napa
# Processing Record 45 of Set 10 | kindu
# Processing Record 46 of Set 10 | devils lake
# Processing Record 47 of Set 10 | marsala
# Processing Record 48 of Set 10 | kelo
# Processing Record 49 of Set 10 | biak
# Processing Record 50 of Set 10 | vigrestad
# Processing Record 1 of Set 11 | wurzburg
# Processing Record 2 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 3 of Set 11 | kahului
# Processing Record 4 of Set 11 | wahiawa
# Processing Record 5 of Set 11 | miyako
# Processing Record 6 of Set 11 | araouane
# Processing Record 7 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 8 of Set 11 | mehamn
# Processing Record 9 of Set 11 | uruzgan
# Processing Record 10 of Set 11 | agsu
# City not found. Skipping...
# Processing Record 11 of Set 11 | pinega
# Processing Record 12 of Set 11 | zhanaozen
# Processing Record 13 of Set 11 | kampong chhnang
# Processing Record 14 of Set 11 | baiyin
# Processing Record 15 of Set 11 | san cristobal
# Processing Record 16 of Set 11 | mbigou
# Processing Record 17 of Set 11 | nadym
# Processing Record 18 of Set 11 | erzin
# Processing Record 19 of Set 11 | monteagudo
# Processing Record 20 of Set 11 | churapcha
# Processing Record 21 of Set 11 | turukhansk
# Processing Record 22 of Set 11 | viedma
# Processing Record 23 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 24 of Set 11 | erenhot
# Processing Record 25 of Set 11 | shaoxing
# Processing Record 26 of Set 11 | wencheng
# Processing Record 27 of Set 11 | bhachau
# Processing Record 28 of Set 11 | terrace
# Processing Record 29 of Set 11 | sidhi
# Processing Record 30 of Set 11 | poum
# Processing Record 31 of Set 11 | sobolevo
# Processing Record 32 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 33 of Set 11 | luderitz
# Processing Record 34 of Set 11 | namatanai
# Processing Record 35 of Set 11 | santa isabel do rio negro
# Processing Record 36 of Set 11 | tungkang
# City not found. Skipping...
# Processing Record 37 of Set 11 | bednodemyanovsk
# City not found. Skipping...
# Processing Record 38 of Set 11 | suez
# Processing Record 39 of Set 11 | kafanchan
# Processing Record 40 of Set 11 | ambulu
# Processing Record 41 of Set 11 | espanola
# Processing Record 42 of Set 11 | palana
# Processing Record 43 of Set 11 | grand forks
# Processing Record 44 of Set 11 | sibolga
# Processing Record 45 of Set 11 | la paz
# Processing Record 46 of Set 11 | nouakchott
# Processing Record 47 of Set 11 | nhulunbuy
# Processing Record 48 of Set 11 | yarmouth
# Processing Record 49 of Set 11 | hilton head island
# Processing Record 50 of Set 11 | thinadhoo
# Processing Record 1 of Set 12 | labuhan
# Processing Record 2 of Set 12 | yukamenskoye
# Processing Record 3 of Set 12 | basay
# Processing Record 4 of Set 12 | okakarara
# Processing Record 5 of Set 12 | ode
# Processing Record 6 of Set 12 | jelling
# Processing Record 7 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 8 of Set 12 | manggar
# Processing Record 9 of Set 12 | huanren
# Processing Record 10 of Set 12 | arua
# Processing Record 11 of Set 12 | pasni
# Processing Record 12 of Set 12 | coos bay
# Processing Record 13 of Set 12 | ngorongoro
# Processing Record 14 of Set 12 | maumere
# Processing Record 15 of Set 12 | jardim do serido
# Processing Record 16 of Set 12 | katherine
# Processing Record 17 of Set 12 | chumikan
# Processing Record 18 of Set 12 | berlevag
# Processing Record 19 of Set 12 | chernyshevskiy
# Processing Record 20 of Set 12 | tarut
# Processing Record 21 of Set 12 | kodinsk
# Processing Record 22 of Set 12 | yar-sale
# Processing Record 23 of Set 12 | takaka
# Processing Record 24 of Set 12 | kirakira
# Processing Record 25 of Set 12 | tura
# Processing Record 26 of Set 12 | basco
# Processing Record 27 of Set 12 | piranshahr
# Processing Record 28 of Set 12 | vaitape
# Processing Record 29 of Set 12 | kloulklubed
# Processing Record 30 of Set 12 | amurzet
# Processing Record 31 of Set 12 | shiyan
# Processing Record 32 of Set 12 | paita
# Processing Record 33 of Set 12 | la romana
# Processing Record 34 of Set 12 | ahipara
# Processing Record 35 of Set 12 | maniitsoq
# Processing Record 36 of Set 12 | kidal
# Processing Record 37 of Set 12 | pecos
# Processing Record 38 of Set 12 | sinjai
# Processing Record 39 of Set 12 | karakol
# Processing Record 40 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 12 | bani walid
# Processing Record 43 of Set 12 | tazovskiy
# Processing Record 44 of Set 12 | marieville
# Processing Record 45 of Set 12 | bois-guillaume
# Processing Record 46 of Set 12 | klaksvik
# Processing Record 47 of Set 12 | san andres
# Processing Record 48 of Set 12 | methoni
# Processing Record 49 of Set 12 | opuwo
# Processing Record 50 of Set 12 | kattivakkam
# Processing Record 1 of Set 13 | phayakkhaphum phisai
# Processing Record 2 of Set 13 | teguise
# Processing Record 3 of Set 13 | wamba
# Processing Record 4 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 5 of Set 13 | chapais
# Processing Record 6 of Set 13 | sabang
# Processing Record 7 of Set 13 | belogorsk
# Processing Record 8 of Set 13 | broome
# Processing Record 9 of Set 13 | mansa
# Processing Record 10 of Set 13 | vilhena
# Processing Record 11 of Set 13 | north bend
# Processing Record 12 of Set 13 | vysokogornyy
# Processing Record 13 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 13 | sampit
# Processing Record 15 of Set 13 | timbiqui
# Processing Record 16 of Set 13 | hambantota
# Processing Record 17 of Set 13 | libreville
# Processing Record 18 of Set 13 | boende
# Processing Record 19 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 20 of Set 13 | stubbekobing
# Processing Record 21 of Set 13 | syasstroy
# Processing Record 22 of Set 13 | ganzhou
# Processing Record 23 of Set 13 | ialibu
# Processing Record 24 of Set 13 | liepaja
# Processing Record 25 of Set 13 | port hardy
# Processing Record 26 of Set 13 | nagbalaye
# Processing Record 27 of Set 13 | varhaug
# Processing Record 28 of Set 13 | samana
# Processing Record 29 of Set 13 | taoudenni
# Processing Record 30 of Set 13 | anchorage
# Processing Record 31 of Set 13 | point pedro
# Processing Record 32 of Set 13 | snasa
# Processing Record 33 of Set 13 | rylsk
# Processing Record 34 of Set 13 | apatou
# Processing Record 35 of Set 13 | tomra
# Processing Record 36 of Set 13 | puerto escondido
# Processing Record 37 of Set 13 | cairns
# Processing Record 38 of Set 13 | butembo
# Processing Record 39 of Set 13 | bharatpur
# Processing Record 40 of Set 13 | svetlyy
# Processing Record 41 of Set 13 | kibungan
# Processing Record 42 of Set 13 | lagos
# Processing Record 43 of Set 13 | okhotsk
# Processing Record 44 of Set 13 | polovinnoye
# Processing Record 45 of Set 13 | prince rupert
# Processing Record 46 of Set 13 | guanare
# Processing Record 47 of Set 13 | spanish town
# Processing Record 48 of Set 13 | goma
# Processing Record 49 of Set 13 | la ronge
# Processing Record 50 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 1 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 14 | eydhafushi
# Processing Record 3 of Set 14 | sovetskiy
# Processing Record 4 of Set 14 | strezhevoy
# Processing Record 5 of Set 14 | nuuk
# Processing Record 6 of Set 14 | berdigestyakh
# Processing Record 7 of Set 14 | stornoway
# Processing Record 8 of Set 14 | atar
# Processing Record 9 of Set 14 | cabedelo
# Processing Record 10 of Set 14 | harwich
# Processing Record 11 of Set 14 | kulhudhuffushi
# Processing Record 12 of Set 14 | petropavl
# Processing Record 13 of Set 14 | yagodnoye
# Processing Record 14 of Set 14 | luchingu
# Processing Record 15 of Set 14 | sisimiut
# Processing Record 16 of Set 14 | yagoua
# Processing Record 17 of Set 14 | makakilo city
# Processing Record 18 of Set 14 | angoche
# Processing Record 19 of Set 14 | puerto castilla
# Processing Record 20 of Set 14 | emerald
# Processing Record 21 of Set 14 | rafsanjan
# Processing Record 22 of Set 14 | saint-pierre
# Processing Record 23 of Set 14 | tailai
# Processing Record 24 of Set 14 | polunochnoye
# Processing Record 25 of Set 14 | nabire
# Processing Record 26 of Set 14 | kawalu
# Processing Record 27 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 28 of Set 14 | malazgirt
# Processing Record 29 of Set 14 | shirokiy
# Processing Record 30 of Set 14 | yekaterinovka
# Processing Record 31 of Set 14 | dickinson
# Processing Record 32 of Set 14 | saint-francois
# Processing Record 33 of Set 14 | saint-augustin
# Processing Record 34 of Set 14 | kamloops
# Processing Record 35 of Set 14 | samfya
# Processing Record 36 of Set 14 | codrington
# Processing Record 37 of Set 14 | flin flon
# Processing Record 38 of Set 14 | oudtshoorn
# Processing Record 39 of Set 14 | broken hill
# Processing Record 40 of Set 14 | trelew
# Processing Record 41 of Set 14 | stony plain
# Processing Record 42 of Set 14 | fowa
# Processing Record 43 of Set 14 | kricim
# City not found. Skipping...
# Processing Record 44 of Set 14 | hun
# Processing Record 45 of Set 14 | baie-saint-paul
# Processing Record 46 of Set 14 | taywarah
# Processing Record 47 of Set 14 | mandalgovi
# Processing Record 48 of Set 14 | antsohihy
# Processing Record 49 of Set 14 | matagami
# Processing Record 50 of Set 14 | phan thiet
# Processing Record 1 of Set 15 | antofagasta
# Processing Record 2 of Set 15 | curup
# Processing Record 3 of Set 15 | hirara
# Processing Record 4 of Set 15 | osa
# Processing Record 5 of Set 15 | buritama
# Processing Record 6 of Set 15 | semporna
# Processing Record 7 of Set 15 | maues
# Processing Record 8 of Set 15 | abashiri
# Processing Record 9 of Set 15 | le port
# Processing Record 10 of Set 15 | hualmay
# Processing Record 11 of Set 15 | morar
# Processing Record 12 of Set 15 | sukhodol
# Processing Record 13 of Set 15 | santana do livramento
# Processing Record 14 of Set 15 | korsakov
# Processing Record 15 of Set 15 | yatou
# Processing Record 16 of Set 15 | sauda
# Processing Record 17 of Set 15 | wolmaranstad
# City not found. Skipping...
# Processing Record 18 of Set 15 | grindavik
# Processing Record 19 of Set 15 | shitkino
# Processing Record 20 of Set 15 | trat
# Processing Record 21 of Set 15 | manado
# Processing Record 22 of Set 15 | douglas
# Processing Record 23 of Set 15 | conceicao do araguaia
# Processing Record 24 of Set 15 | goderich
# Processing Record 25 of Set 15 | olafsvik
# Processing Record 26 of Set 15 | vanimo
# Processing Record 27 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 28 of Set 15 | quime
# Processing Record 29 of Set 15 | mookane
# Processing Record 30 of Set 15 | saquena
# Processing Record 31 of Set 15 | altay
# Processing Record 32 of Set 15 | karpuninskiy
# City not found. Skipping...
# Processing Record 33 of Set 15 | chicama
# Processing Record 34 of Set 15 | vagur
# Processing Record 35 of Set 15 | jieshi
# Processing Record 36 of Set 15 | batemans bay
# Processing Record 37 of Set 15 | collie
# Processing Record 38 of Set 15 | montepuez
# Processing Record 39 of Set 15 | bara
# Processing Record 40 of Set 15 | ugoofaaru
# Processing Record 41 of Set 15 | chimore
# Processing Record 42 of Set 15 | lazaro cardenas
# Processing Record 43 of Set 15 | sept-iles
# Processing Record 44 of Set 15 | coihueco
# Processing Record 45 of Set 15 | jiamusi
# Processing Record 46 of Set 15 | urusha
# Processing Record 47 of Set 15 | aruppukkottai
# Processing Record 48 of Set 15 | gillette
# Processing Record 49 of Set 15 | parana
# Processing Record 50 of Set 15 | sumenep
# Processing Record 1 of Set 16 | bilibino
# Processing Record 2 of Set 16 | pokrovsk
# Processing Record 3 of Set 16 | clarence town
# Processing Record 4 of Set 16 | makat
# Processing Record 5 of Set 16 | ust-maya
# Processing Record 6 of Set 16 | turka
# Processing Record 7 of Set 16 | ambilobe
# Processing Record 8 of Set 16 | ampanihy
# Processing Record 9 of Set 16 | las tunas
# Processing Record 10 of Set 16 | chateauroux
# Processing Record 11 of Set 16 | natal
# Processing Record 12 of Set 16 | banmo
# City not found. Skipping...
# Processing Record 13 of Set 16 | igrim
# Processing Record 14 of Set 16 | nosy varika
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Get the number of cities
len(city_data)
# Out:
# 697

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City      Lat       Lng Weather Description  Max Temp  Humidity  \
# 0   Clyde River  70.4692  -68.5914       broken clouds     39.43        93
# 1  Punta Arenas -53.1500  -70.9167          light rain     39.31        87
# 2      Zyryanka  65.7500  150.8500       broken clouds     48.40        56
# 3          Auki  -8.7676  160.7034    scattered clouds     78.62        81
# 4     Raudeberg  61.9875    5.1352          few clouds     52.86        81
#
#    Cloudiness  Wind Speed Country
# 0          75        9.22      CA
# 1          40       28.77      CL
# 2          68        7.02      RU
# 3          38        5.82      SB
# 4          21       16.64      NO

# %%
# Reorder the columns so they are easier to read. 
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

# Assign city data df the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Clyde River      CA  70.4692  -68.5914     39.43        93          75
# 1  Punta Arenas      CL -53.1500  -70.9167     39.31        87          40
# 2      Zyryanka      RU  65.7500  150.8500     48.40        56          68
# 3          Auki      SB  -8.7676  160.7034     78.62        81          38
# 4     Raudeberg      NO  61.9875    5.1352     52.86        81          21
#
#    Wind Speed Weather Description
# 0        9.22       broken clouds
# 1       28.77          light rain
# 2        7.02       broken clouds
# 3        5.82    scattered clouds
# 4       16.64          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
